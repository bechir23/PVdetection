# %%
# %pip install -q git+https://github.com/THU-MIG/yolov10.git
# %pip install -q supervision
# %pip install ultralytics
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print(torch.cuda.device_count())
# Out:
# 1

# %%
# %pip install huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 21.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !yolo task=detect mode=train model='/teamspace/studios/this_studio/runs/detect/train/weights/checkpoint.pt' data='/teamspace/studios/this_studio/folder/data.yaml' epochs=15 batch=24 workers=6
# Out:
# New https://pypi.org/project/ultralytics/8.2.39 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA A10G, 22724MiB)
# ...

# %%
import torch

# Check if CUDA is available
cuda_available = torch.cuda.is_available()
print(f"CUDA Available: {cuda_available}")

if cuda_available:
    # Get the number of available CUDA devices
    cuda_device_count = torch.cuda.device_count()
    print(f"Number of CUDA devices: {cuda_device_count}")
else:
    print("No CUDA devices available.")
# Out:
# CUDA Available: False
# No CUDA devices available.

# %%
import torch

print("PyTorch version:", torch.__version__)
# Out:
# PyTorch version: 2.2.1+cu121

# %%
! nvidia-smi
# Out:
# zsh:1: command not found: nvidia-smi
